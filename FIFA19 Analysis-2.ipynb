# %% [markdown]
# # FIFA 19 Exploratory Data Analysis and Classification
#
# ----
#
# In this notebook, I will be running an in-depth analysis on one of my favourite FIFA games, FIFA 2019. I particularly enjoyed this release because it was the first one that featured UEFA club competitions, in particular the UEFA champions league which is a competition that I have always enjoyed watching.
#
# This notebook will be using a comprehensive FIFA19 player data set from Kaggle which includes over 80 player attributes. I will first be running an **exploratory data analysis** to gain a general overview and distribution of the data set and identify interesting trends and insights. Following this section, I will run a **K Nearest Neighbors clustering algorithm** to see if I can classify a subset of the dataset into different groups.
#
# ![Screen%20Shot%202022-01-28%20at%201.32.33%20PM.png](attachment:Screen%20Shot%202022-01-28%20at%201.32.33%20PM.png)

# %% [markdown]
# ## Importing and cleaning data

# %% [markdown]
# #### Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #### Importing the data

# %%
data = pd.read_csv('~/Desktop/Kaggle Projects/fifa19_data.csv')

# %% [markdown]
# #### Quick summaries

# %%
data.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
data.describe()
# Out:
#          Unnamed: 0             ID           Age       Overall     Potential  \
# count  18207.000000   18207.000000  18207.000000  18207.000000  18207.000000
# mean    9103.000000  214298.338606     25.122206     66.238699     71.307299
# std     5256.052511   29965.244204      4.669943      6.908930      6.136496
# min        0.000000      16.000000     16.000000     46.000000     48.000000
# 25%     4551.500000  200315.500000     21.000000     62.000000     67.000000
# 50%     9103.000000  221759.000000     25.000000     66.000000     71.000000
# 75%    13654.500000  236529.500000     28.000000     71.000000     75.000000
# max    18206.000000  246620.000000     45.000000     94.000000     95.000000
#
#             Special  International Reputation     Weak Foot   Skill Moves  \
# count  18207.000000              18159.000000  18159.000000  18159.000000
# mean    1597.809908                  1.113222      2.947299      2.361308
# ...

# %%
data.shape
# Out:
# (18207, 89)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 89 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                18207 non-null  int64
#  1   ID                        18207 non-null  int64
#  2   Name                      18207 non-null  object
#  3   Age                       18207 non-null  int64
#  4   Photo                     18207 non-null  object
#  5   Nationality               18207 non-null  object
#  6   Flag                      18207 non-null  object
#  7   Overall                   18207 non-null  int64
#  8   Potential                 18207 non-null  int64
#  9   Club                      17966 non-null  object
#  10  Club Logo                 18207 non-null  object
#  11  Value                     18207 non-null  object
#  12  Wage                      18207 non-null  object
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0           0
# ID                   0
# Name                 0
# Age                  0
# Photo                0
#                   ...
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Release Clause    1564
# Length: 89, dtype: int64

# %% [markdown]
# #### Observations
#
# * A quick look at the data shows that there are a lot of columns. I will not be using all of them for this analysis, so I will need to choose which attributes to leave out.
#
# * There are several columns with missing values, so I will need to fill those in with values depending on what is most reasonable for each attribute.

# %%
data['ShortPassing'].fillna(data['ShortPassing'].mean(), inplace = True)
data['Volleys'].fillna(data['Volleys'].mean(), inplace = True)
data['Dribbling'].fillna(data['Dribbling'].mean(), inplace = True)
data['Curve'].fillna(data['Curve'].mean(), inplace = True)
data['FKAccuracy'].fillna(data['FKAccuracy'], inplace = True)
data['LongPassing'].fillna(data['LongPassing'].mean(), inplace = True)
data['BallControl'].fillna(data['BallControl'].mean(), inplace = True)
data['HeadingAccuracy'].fillna(data['HeadingAccuracy'].mean(), inplace = True)
data['Finishing'].fillna(data['Finishing'].mean(), inplace = True)
data['Crossing'].fillna(data['Crossing'].mean(), inplace = True)
data['Weight'].fillna('200lbs', inplace = True)
data['Contract Valid Until'].fillna(2019, inplace = True)
data['Height'].fillna("5'11", inplace = True)
data['Loaned From'].fillna('None', inplace = True)
data['Joined'].fillna('Jul 1, 2018', inplace = True)
data['Jersey Number'].fillna(8, inplace = True)
data['Body Type'].fillna('Normal', inplace = True)
data['Position'].fillna('ST', inplace = True)
data['Club'].fillna('No Club', inplace = True)
data['Work Rate'].fillna('Medium/ Medium', inplace = True)
data['Skill Moves'].fillna(data['Skill Moves'].median(), inplace = True)
data['Weak Foot'].fillna(3, inplace = True)
data['Preferred Foot'].fillna('Right', inplace = True)
data['International Reputation'].fillna(1, inplace = True)
data['Wage'].fillna('€200K', inplace = True)

# %%
data.fillna(0,inplace = True)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# Let's take a look at Canadian players in FIFA19

# %%
Canadians = data[data['Nationality'] == 'Canada'][['Name', 'Overall', 'Position','Club']]
Canadians
# Out:
#                Name  Overall Position                    Club
# 2003       C. Larin       75       ST             Beşiktaş JK
# 2107     J. Hoilett       74       LM            Cardiff City
# 2276   L. Cavallini       74       RS               Puebla FC
# 2862     S. Arfield       73      LCM              Rangers FC
# 2984      M. Borjan       73       GK                 No Club
# ...             ...      ...      ...                     ...
# 17509  D. Gutiérrez       54       LM            CD Palestino
# 17888     S. Melvin       52       GK  Vancouver Whitecaps FC
# 17900    A. Daniels       51      CAM              Toronto FC
# 17901       J. Dunn       51       CB              Toronto FC
# 18199  M. Baldisimo       47       CM  Vancouver Whitecaps FC
#
# [64 rows x 4 columns]

# %% [markdown]
# As we can see, the highest rated Canadian is Cyle Larin at 75. At this point in time Davies is not even in the top 5. 3 years later in FIFA22, he will go on to have a rating of 82!
#
# For now, let's see what his rating was back in 2019.

# %%
Canadians[Canadians['Name'] == 'A. Davies'][['Name', 'Overall', 'Position']]
# Out:
#            Name  Overall Position
# 3692  A. Davies       72       RM

# %% [markdown]
# What a difference!

# %% [markdown]
# How about the whitecaps? 2019 was a difficult year, with a finish of dead last in the Western conference. But let's have a look at the squad and ratings.

# %%
Whitecaps = data[data['Club'] == 'Vancouver Whitecaps FC'][['Name', 'Position', 'Overall', 'Nationality', 'Age']]
Whitecaps
# Out:
#                Name Position  Overall    Nationality  Age
# 2455      K. Kamara       ST       74   Sierra Leone   33
# 2559      K. Waston      RCB       74     Costa Rica   30
# 3535         Felipe      RCM       72         Brazil   27
# 3692      A. Davies       RM       72         Canada   17
# 3929      A. Ghazal      CDM       72          Egypt   26
# 5588       Y. Reyna       CF       70           Peru   24
# 5828     C. Techera       RM       69        Uruguay   26
# 6630       J. Mutch       CM       68        England   26
# 6996      E. Juárez       CM       68         Mexico   30
# 7203   S. Marinović       GK       68    New Zealand   26
# 7278       M. Emnes       ST       68    Netherlands   30
# 7588       A. Maund       CB       68  United States   27
# 7715         J. Aja       CB       67        Uruguay   25
# 8509   J. Nerwinski       RB       67  United States   23
# 8562    A. Blondell       ST       67      Venezuela   24
# ...

# %% [markdown]
# #### Let's now take a look at the best players in each category

# %%
data.drop(['Unnamed: 0','Photo','Flag','Club Logo'],axis=1,inplace=True)

# %%
pr_cols=['Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']
print('BEST IN DIFFERENT ASPECTS :')
print('_________________________\n\n')
i=0
while i < len(pr_cols):
    print('Best {0} : {1}'.format(pr_cols[i],data.loc[data[pr_cols[i]].idxmax()][1]))
    i += 1
# Out:
# BEST IN DIFFERENT ASPECTS :
# _________________________
#
#
# Best Crossing : K. De Bruyne
# Best Finishing : L. Messi
# Best HeadingAccuracy : Naldo
# Best ShortPassing : L. Modrić
# Best Volleys : E. Cavani
# Best Dribbling : L. Messi
# Best Curve : Quaresma
# Best FKAccuracy : L. Messi
# Best LongPassing : T. Kroos
# Best BallControl : L. Messi
# Best Acceleration : Douglas Costa
# Best SprintSpeed : K. Mbappé
# Best Agility : Neymar Jr
# Best Reactions : Cristiano Ronaldo
# Best Balance : Bernard
# Best ShotPower : Cristiano Ronaldo
# Best Jumping : Cristiano Ronaldo
# Best Stamina : N. Kanté
# Best Strength : A. Akinfenwa
# Best LongShots : L. Messi
# Best Aggression : B. Pearson
# Best Interceptions : N. Kanté
# Best Positioning : Cristiano Ronaldo
# Best Vision : L. Messi
# Best Penalties : M. Balotelli
# Best Composure : L. Messi
# Best Marking : A. Barzagli
# Best StandingTackle : G. Chiellini
# Best SlidingTackle : Sergio Ramos
# Best GKDiving : De Gea
# ...

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# #### Age Distribution

# %%
sns.set(style ="dark", palette="colorblind", color_codes=True)
x = data.Age
plt.figure(figsize=(12,8))
ax = sns.histplot(x, bins = 58, kde = False, color='g')
ax.set_xlabel(xlabel="Player\'s age", fontsize=16)
ax.set_ylabel(ylabel='Number of players', fontsize=16)
ax.set_title(label='Players Age Distribution', fontsize=20)
plt.show()

# %% [markdown]
# Who is the oldest player in the game?

# %%
oldest = data.sort_values('Age', ascending = False)[['Name', 'Nationality', 'Age']].head(1)
print(oldest)
# Out:
#           Name Nationality  Age
# 4741  O. Pérez      Mexico   45

# %% [markdown]
# What about the youngest?

# %%
youngest = data.sort_values('Age',ascending = True)[['Name', 'Nationality', 'Age']].head(1)
print(youngest)
# Out:
#             Name Nationality  Age
# 18206  G. Nugent     England   16

# %% [markdown]
# #### Positions

# %% [markdown]
# Now let's take a look at the distribution of positions

# %%
plt.figure(figsize = (18,8))
ax = sns.countplot(x = 'Position', data = data);
ax.set_title(label='Distribution of positions', fontsize=20);

# %% [markdown]
# So who are the best players for each position?

# %%
data.iloc[data.groupby(data['Position'])['Overall'].idxmax()][['Position', 'Name',
                                                               'Age', 'Club', 'Nationality']].style.background_gradient('Reds')
# Out:
# <style  type="text/css" >
# #T_449927b6_8161_11ec_866c_acde48001122row0_col2,#T_449927b6_8161_11ec_866c_acde48001122row4_col2,#T_449927b6_8161_11ec_866c_acde48001122row5_col2,#T_449927b6_8161_11ec_866c_acde48001122row10_col2,#T_449927b6_8161_11ec_866c_acde48001122row11_col2,#T_449927b6_8161_11ec_866c_acde48001122row19_col2{
#             background-color:  #f44f39;
#             color:  #000000;
#         }#T_449927b6_8161_11ec_866c_acde48001122row1_col2,#T_449927b6_8161_11ec_866c_acde48001122row18_col2{
#             background-color:  #8a0812;
#             color:  #f1f1f1;
#         }#T_449927b6_8161_11ec_866c_acde48001122row2_col2,#T_449927b6_8161_11ec_866c_acde48001122row12_col2{
#             background-color:  #d52221;
#             color:  #f1f1f1;
#         }#T_449927b6_8161_11ec_866c_acde48001122row3_col2,#T_449927b6_8161_11ec_866c_acde48001122row15_col2,#T_449927b6_8161_11ec_866c_acde48001122row20_col2{
#             background-color:  #fc8161;
# ...

# %% [markdown]
# #### Analysis on clubs

# %% [markdown]
# Now let's take a look at distributions and insights related to the different clubs across FIFA19

# %% [markdown]
# **Overall Scores**

# %%
some_clubs = ('Arsenal','Manchester City',
             'Tottenham Hotspur', 'FC Barcelona', 'FC Bayern München', 'Manchester United', 'Chelsea', 'Real Madrid','Atlético Madrid','Juventus')

data_clubs = data.loc[data['Club'].isin(some_clubs) & data['Overall']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.boxplot(x = data_clubs['Club'], y = data_clubs['Overall'], palette = 'inferno')
ax.set_xlabel(xlabel = 'Some Popular Clubs', fontsize = 9)
ax.set_ylabel(ylabel = 'Overall Score', fontsize = 9)
ax.set_title(label = 'Distribution of Overall Scores for Popular Clubs', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# **Age**

# %%
some_clubs = ('Arsenal','Manchester City',
             'Tottenham Hotspur', 'FC Barcelona', 'FC Bayern München', 'Manchester United', 'Chelsea', 'Real Madrid','Atlético Madrid','Juventus')

data_club = data.loc[data['Club'].isin(some_clubs) & data['Wage']]

plt.rcParams['figure.figsize'] = (15, 8)
ax = sns.boxenplot(x = 'Club', y = 'Age', data = data_club, palette = 'magma')
ax.set_xlabel(xlabel = 'Names of some popular Clubs', fontsize = 10)
ax.set_ylabel(ylabel = 'Distribution', fontsize = 10)
ax.set_title(label = 'Distribution of Ages in Popular Clubs', fontsize = 20)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# Now let's look at the clubs who have the highest amount of diversity of nationalities for their players

# %%
nationalities = data.groupby(data['Club'])['Nationality'].nunique().sort_values(ascending = False).head(10)
nationalities
# Out:
# Club
# No Club                   28
# Brighton & Hove Albion    21
# Fulham                    19
# Udinese                   18
# Napoli                    18
# Empoli                    18
# Eintracht Frankfurt       18
# West Ham United           18
# AS Monaco                 18
# Lazio                     18
# Name: Nationality, dtype: int64

# %% [markdown]
# And what are the most common nationalities in the game?

# %%
data['Nationality'].value_counts().head(80).plot.bar(color = 'orange', figsize = (20, 7))
plt.title('Different Nations Participating in FIFA 2019', fontsize = 30, fontweight = 20)
plt.xlabel('Name of The Country')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ## Clustering

# %%
data.describe().columns
# Out:
# Index(['ID', 'Age', 'Overall', 'Potential', 'Special',
#        'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
#        'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
#        'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
#        'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
#        'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
#        'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes'],
#       dtype='object')

# %%
new_data = data[['Name', 'Age', 'Overall', 'Potential', 'Special',
       'International Reputation', 'Weak Foot', 'Skill Moves', 'Jersey Number',
       'Crossing', 'Finishing', 'HeadingAccuracy', 'ShortPassing', 'Volleys',
       'Dribbling', 'Curve', 'FKAccuracy', 'LongPassing', 'BallControl',
       'Acceleration', 'SprintSpeed', 'Agility', 'Reactions', 'Balance',
       'ShotPower', 'Jumping', 'Stamina', 'Strength', 'LongShots',
       'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
       'Composure', 'Marking', 'StandingTackle', 'SlidingTackle', 'GKDiving',
       'GKHandling', 'GKKicking', 'GKPositioning', 'GKReflexes']]

# %%
new_data.head()
# Out:
#                 Name  Age  Overall  Potential  Special  \
# 0           L. Messi   31       94         94     2202
# 1  Cristiano Ronaldo   33       94         94     2228
# 2          Neymar Jr   26       92         93     2143
# 3             De Gea   27       91         93     1471
# 4       K. De Bruyne   27       91         92     2281
#
#    International Reputation  Weak Foot  Skill Moves  Jersey Number  Crossing  \
# 0                       5.0        4.0          4.0           10.0      84.0
# 1                       5.0        4.0          5.0            7.0      84.0
# 2                       5.0        5.0          5.0           10.0      79.0
# 3                       4.0        3.0          1.0            1.0      17.0
# 4                       4.0        5.0          4.0            7.0      93.0
#
#    ...  Penalties  Composure  Marking  StandingTackle  SlidingTackle  \
# 0  ...       75.0       96.0     33.0            28.0           26.0
# ...

# %%
df = new_data[new_data.Overall > 86]
df
# Out:
#                  Name  Age  Overall  Potential  Special  \
# 0            L. Messi   31       94         94     2202
# 1   Cristiano Ronaldo   33       94         94     2228
# 2           Neymar Jr   26       92         93     2143
# 3              De Gea   27       91         93     1471
# 4        K. De Bruyne   27       91         92     2281
# 5           E. Hazard   27       91         91     2142
# 6           L. Modrić   32       91         91     2280
# 7           L. Suárez   31       91         91     2346
# 8        Sergio Ramos   32       91         91     2201
# 9            J. Oblak   25       90         93     1331
# 10     R. Lewandowski   29       90         90     2152
# 11           T. Kroos   28       90         90     2190
# 12           D. Godín   32       90         90     1946
# 13        David Silva   32       90         90     2115
# 14           N. Kanté   27       89         90     2189
# 15          P. Dybala   24       89         94     2092
# ...

# %%
pd.set_option('display.max_rows', 70)
df.isnull().sum()
# Out:
# Name                        0
# Age                         0
# Overall                     0
# Potential                   0
# Special                     0
# International Reputation    0
# Weak Foot                   0
# Skill Moves                 0
# Jersey Number               0
# Crossing                    0
# Finishing                   0
# HeadingAccuracy             0
# ShortPassing                0
# Volleys                     0
# Dribbling                   0
# Curve                       0
# FKAccuracy                  0
# LongPassing                 0
# BallControl                 0
# Acceleration                0
# SprintSpeed                 0
# Agility                     0
# Reactions                   0
# Balance                     0
# ShotPower                   0
# Jumping                     0
# Stamina                     0
# Strength                    0
# LongShots                   0
# Aggression                  0
# Interceptions               0
# ...

# %%
names = df.Name.tolist()
df = df.drop(['Name'], axis = 1)

# %%
df.head()
# Out:
#    Age  Overall  Potential  Special  International Reputation  Weak Foot  \
# 0   31       94         94     2202                       5.0        4.0
# 1   33       94         94     2228                       5.0        4.0
# 2   26       92         93     2143                       5.0        5.0
# 3   27       91         93     1471                       4.0        3.0
# 4   27       91         92     2281                       4.0        5.0
#
#    Skill Moves  Jersey Number  Crossing  Finishing  ...  Penalties  Composure  \
# 0          4.0           10.0      84.0       95.0  ...       75.0       96.0
# 1          5.0            7.0      84.0       94.0  ...       85.0       95.0
# 2          5.0           10.0      79.0       87.0  ...       81.0       94.0
# 3          1.0            1.0      17.0       13.0  ...       40.0       68.0
# 4          4.0            7.0      93.0       82.0  ...       79.0       88.0
#
# ...

# %%
from sklearn import preprocessing

x = df.values
scaler = preprocessing.MinMaxScaler()
x_scaled = scaler.fit_transform(x)
X_norm = pd.DataFrame(x_scaled)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components = 2)
reduced = pd.DataFrame(pca.fit_transform(X_norm))

# %% [markdown]
# ## K-Means Clustering

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters = 5)

kmeans = kmeans.fit(reduced)

labels = kmeans.predict(reduced)

centroid = kmeans.cluster_centers_

clusters = kmeans.labels_.tolist()

# %%
reduced['cluster'] = clusters
reduced['name'] = names
reduced.columns = ['x', 'y', 'cluster', 'name']
reduced.head()
# Out:
#           x         y  cluster               name
# 0 -1.115799 -1.266128        4           L. Messi
# 1 -1.065857 -1.014478        4  Cristiano Ronaldo
# 2 -1.019252 -1.187401        4          Neymar Jr
# 3  2.916667 -0.518266        2             De Gea
# 4 -1.078129 -0.192870        1       K. De Bruyne

# %% [markdown]
# # Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set(style = 'white')

ax = sns.lmplot(x = 'x', y ='y', hue = 'cluster', data = reduced, legend = False, 
                fit_reg = False, height = 15, scatter_kws ={'s': 250})

texts = []
for x, y, s in zip(reduced.x, reduced.y, reduced.name):
    texts.append(plt.text(x,y,s))
    
ax.set(ylim=(-2,2))
plt.tick_params(labelsize=15)
plt.xlabel('PC 1', fontsize = 20)
plt.ylabel('PC 2', fontsize = 20)

plt.show()
